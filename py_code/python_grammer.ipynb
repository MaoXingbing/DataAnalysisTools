# %%
import math
res=math.sqrt(8)
print(res)
# Out:
# 2.8284271247461903

# %%
#计算1加到100
res=0
for i in range(1,101,3):
    res+=i
print(res)
# Out:
# 1717

# %%
#判断语句
num=int(input("心情怎么样："))
if num>=10:
    print("Yes")
else:
    print("No")
# Out:
# No

# %%
num=int(input("give number："))
if num==0:
    print('zero')
elif num==1:
    print('one')
elif num==2:
    print('3')
else:
    print('all not')
# Out:
# one

# %%
#列表
num=[1,2,3]
print(num)
# Out:
# [1, 2, 3]

# %%
#元组
tupl={("xiaoming",23):123,
       ('xiaoli',33):322}
# print(tupl[("xiaoming",23)])
# print(1 in tupl)
# print(('xiaoli',33) in tupl)
tupl={1: 2}
print(tupl[1])
# Out:
# 2
